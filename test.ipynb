# %%
import requests
import tensorflow as tf
import numpy as np
import json
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#      Age  Gender        BMI  PhysicalActivityLevel  ObesityCategory
# 0     56       1  23.891783                      4                0
# 1     69       1  33.395209                      2                3
# 2     46       0  25.817737                      4                2
# 3     32       1  29.912247                      3                2
# 4     60       1  20.487903                      3                0
# ..   ...     ...        ...                    ...              ...
# 995   18       1  26.480345                      4                2
# 996   35       0  35.830783                      1                3
# 997   49       0  32.146036                      1                3
# 998   64       1  21.505965                      4                0
# 999   66       0  23.517168                      1                0
#
# [1000 rows x 5 columns]

# %%
data_to_predict = df.iloc[0, :-1]
data_to_predict
test_data = data_to_predict.to_dict()

# %%
data = json.dumps({"instances": [test_data]})
print(data)
# Out:
# {"instances": [{"Age": 56.0, "Gender": 1.0, "BMI": 23.89178262396797, "PhysicalActivityLevel": 4.0}]}

# %%
response = requests.post("http://localhost:8080/v1/models/obesity_model:predict", data=data)

# %%
if response.status_code == 200:
    predictions = response.json().get("predictions")
    if predictions:
        predicted_quality = round(predictions[0][0])
        print("Predicted quality:", predicted_quality)
    else:
        print("No predictions returned, but the request was successful.")
else:
    print("Error:", response.text)
# Out:
# Error:
